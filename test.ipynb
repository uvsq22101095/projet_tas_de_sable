# %%
test

# %%
import tkinter as tk 
import random
#fonctions pour les boutons ajouter et soustraire
def AJOUTER () :
    print(3+4)

def SOUSTRAIRE () :
    print(3+4)



#fonction pour le code principal
def MAIN ():
    print(2+3)




CANVAS_WIDTH, CANVAS_HEIGHT = 500, 500

root = tk.Tk()

root.title(" Tas de sable ")


boutton_avalanche=tk.Button(root, text="avalanche", bg="grey100", fg="black", command=MAIN)



boutton_ajouter1=tk.Button(root, text="ajouter", bg="grey100", fg="black", command=AJOUTER)
boutton_ajouter2=tk.Button(root, text="ajouter", bg="grey100", fg="black", command=AJOUTER)
boutton_ajouter3=tk.Button(root, text="ajouter", bg="grey100", fg="black", command=AJOUTER)

boutton_soustraire1=tk.Button(root, text="soustraire", bg="grey100", fg="black", command=SOUSTRAIRE)
boutton_soustraire2=tk.Button(root, text="soustraire", bg="grey100", fg="black", command=SOUSTRAIRE)
boutton_soustraire3=tk.Button(root, text="soustraire", bg="grey100", fg="black", command=SOUSTRAIRE)



canvas3 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas2 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")

canvas.create_line((1/3)*CANVAS_WIDTH, 0, (1/3)*CANVAS_WIDTH, CANVAS_HEIGHT,fill="white")
canvas.create_line((2/3)*CANVAS_WIDTH, 0, (2/3)*CANVAS_WIDTH, CANVAS_HEIGHT,fill="white")
canvas.create_line(0, (1/3)*CANVAS_HEIGHT, CANVAS_WIDTH, (1/3)*CANVAS_HEIGHT,fill="white")
canvas.create_line(0, (2/3)*CANVAS_HEIGHT, CANVAS_WIDTH, (2/3)*CANVAS_HEIGHT,fill="white")


boutton_avalanche.grid(column=2, row=0)

boutton_ajouter1.grid(column=3, row=1)
boutton_ajouter2.grid(column=3, row=2)
boutton_ajouter3.grid(column=3, row=3)

boutton_soustraire1.grid(column=1, row=1)
boutton_soustraire2.grid(column=1, row=2)
boutton_soustraire3.grid(column=1, row=3)

canvas.grid(column=2, row=1, rowspan=3)

root.mainloop()

# %% [markdown]
# test2

# %%
import tkinter as tk 
import random
#fonctions pour les boutons ajouter et soustraire
def AJOUTER () :
    print(3+4)

def SOUSTRAIRE () :
    print(3+4)



#fonction pour le code principal
def MAIN ():
    L1=[1,2,3]
    L2=[1,2,3]
    L3=[1,2,3]
    L=[L1 ,L2 ,L3]

    for i in range (3):
        L1[i]=int(random.randint(0,5))
    for i in range (3):
        L2[i]=int(random.randint(0,5))
    for i in range (3):
        L3[i]=int(random.randint(0,5))
    return(L)

def MAIN1 ():
    L1=[1,2,3]
    for i in range (3):
        L1[i]=int(random.randint(0,5))

    return(L1)

def MAIN2 ():
    L2=[1,2,3]
    for i in range (3):
        L2[i]=int(random.randint(0,5))
    return(L2)
    
def MAIN3 ():
    L3=[1,2,3]
    for i in range (3):
        L3[i]=int(random.randint(0,5))
    return(L3)

def MAIN4 (L1,L2,L3):
    L=[L1,L2,L3]
    return(L)



def AFFICHAGE (MAIN4):
    L=MAIN4

###########################################################################
    if L[0][0] == 0:
        canvas1_1.create_text(5,5,text="0",fill="white")
    elif L[0][0] == 1 :
        canvas1_1.create_text(5,5,text="1",fill="white")
    elif L[0][0] == 2 :
        canvas1_1.create_text(5,5,text="2",fill="white")
    elif L[0][0] == 3 :
        canvas1_1.create_text(5,5,text="3",fill="white")
    elif L[0][0] == 4 :
        canvas1_1.create_text(5,5,text="4",fill="white")
    elif L[0][0] == 5 :
        canvas1_1.create_text(5,5,text="5",fill="white")

    if L[0][1] == 0:
        canvas1_2.create_text(5,5,text="0",fill="white")
    elif L[0][1] == 1 :
        canvas1_2.create_text(5,5,text="1",fill="white")
    elif L[0][1] == 2 :
        canvas1_2.create_text(5,5,text="2",fill="white")
    elif L[0][1] == 3 :
        canvas1_2.create_text(5,5,text="3",fill="white")
    elif L[0][1] == 4 :
        canvas1_2.create_text(5,5,text="4",fill="white")
    elif L[0][1] == 5 :
        canvas1_2.create_text(5,5,text="5",fill="white")

    if L[0][2] == 0:
        canvas1_3.create_text(5,5,text="0",fill="white")
    elif L[0][2] == 1 :
        canvas1_3.create_text(5,5,text="1",fill="white")
    elif L[0][2] == 2 :
        canvas1_3.create_text(5,5,text="2",fill="white")
    elif L[0][2] == 3 :
        canvas1_3.create_text(5,5,text="3",fill="white")
    elif L[0][2] == 4 :
        canvas1_3.create_text(5,5,text="4",fill="white")
    elif L[0][2] == 5 :
        canvas1_3.create_text(5,5,text="5",fill="white")
########################################################################

    if L[1][0] == 0:
        canvas2_1.create_text(5,5,text="0",fill="white")
    elif L[1][0] == 1 :
        canvas2_1.create_text(5,5,text="1",fill="white")
    elif L[1][0] == 2 :
        canvas2_1.create_text(5,5,text="2",fill="white")
    elif L[1][0] == 3 :
        canvas2_1.create_text(5,5,text="3",fill="white")
    elif L[1][0] == 4 :
        canvas2_1.create_text(5,5,text="4",fill="white")
    elif L[1][0] == 5 :
        canvas2_1.create_text(5,5,text="5",fill="white")

    if L[1][1] == 0:
        canvas2_2.create_text(5,5,text="0",fill="white")
    elif L[1][1] == 1 :
        canvas2_2.create_text(5,5,text="1",fill="white")
    elif L[1][1] == 2 :
        canvas2_2.create_text(5,5,text="2",fill="white")
    elif L[1][1] == 3 :
        canvas2_2.create_text(5,5,text="3",fill="white")
    elif L[1][1] == 4 :
        canvas2_2.create_text(5,5,text="4",fill="white")
    elif L[1][1] == 5 :
        canvas2_2.create_text(5,5,text="5",fill="white")

    if L[1][2] == 0:
        canvas2_3.create_text(5,5,text="0",fill="white")
    elif L[1][2] == 1 :
        canvas2_3.create_text(5,5,text="1",fill="white")
    elif L[1][2] == 2 :
        canvas2_3.create_text(5,5,text="2",fill="white")
    elif L[1][2] == 3 :
        canvas2_3.create_text(5,5,text="3",fill="white")
    elif L[1][2] == 4 :
        canvas2_3.create_text(5,5,text="4",fill="white")
    elif L[1][2] == 5 :
        canvas2_3.create_text(5,5,text="5",fill="white")

############################################################################


    if L[3][0] == 0:
        canvas3_1.create_text(5,5,text="0",fill="white")
    elif L[3][0] == 1 :
        canvas3_1.create_text(5,5,text="1",fill="white")
    elif L[3][0] == 2 :
        canvas3_1.create_text(5,5,text="2",fill="white")
    elif L[3][0] == 3 :
        canvas3_1.create_text(5,5,text="3",fill="white")
    elif L[3][0] == 4 :
        canvas3_1.create_text(5,5,text="4",fill="white")
    elif L[3][0] == 5 :
        canvas3_1.create_text(5,5,text="5",fill="white")

    if L[3][1] == 0:
        canvas3_2.create_text(5,5,text="0",fill="white")
    elif L[3][1] == 1 :
        canvas3_2.create_text(5,5,text="1",fill="white")
    elif L[3][1] == 2 :
        canvas3_2.create_text(5,5,text="2",fill="white")
    elif L[3][1] == 3 :
        canvas3_2.create_text(5,5,text="3",fill="white")
    elif L[3][1] == 4 :
        canvas3_2.create_text(5,5,text="4",fill="white")
    elif L[3][1] == 5 :
        canvas3_2.create_text(5,5,text="5",fill="white")

    if L[3][2] == 0:
        canvas3_3.create_text(5,5,text="0",fill="white")
    elif L[3][2] == 1 :
        canvas3_3.create_text(5,5,text="1",fill="white")
    elif L[3][2] == 2 :
        canvas3_3.create_text(5,5,text="2",fill="white")
    elif L[3][2] == 3 :
        canvas3_3.create_text(5,5,text="3",fill="white")
    elif L[3][2] == 4 :
        canvas3_3.create_text(5,5,text="4",fill="white")
    elif L[3][2] == 5 :
        canvas3_3.create_text(5,5,text="5",fill="white")




        



CANVAS_WIDTH, CANVAS_HEIGHT = 10, 10

root = tk.Tk()

root.title(" Tas de sable ")


boutton_grille=tk.Button(root, text="grille", bg="grey100", fg="black", command=MAIN4(MAIN1,MAIN2,MAIN3))



boutton_ajouter1=tk.Button(root, text="ajouter", bg="grey100", fg="black", command=AJOUTER)
boutton_ajouter2=tk.Button(root, text="ajouter", bg="grey100", fg="black", command=AJOUTER)
boutton_ajouter3=tk.Button(root, text="ajouter", bg="grey100", fg="black", command=AJOUTER)

boutton_soustraire1=tk.Button(root, text="soustraire", bg="grey100", fg="black", command=SOUSTRAIRE)
boutton_soustraire2=tk.Button(root, text="soustraire", bg="grey100", fg="black", command=SOUSTRAIRE)
boutton_soustraire3=tk.Button(root, text="soustraire", bg="grey100", fg="black", command=SOUSTRAIRE)


canvas1_1 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas1_2 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas1_3 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas2_1 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas2_2 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas2_3 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas3_1 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas3_2 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")
canvas3_3 = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")



boutton_grille.grid(column=2, row=0, columnspan=3)

boutton_ajouter1.grid(column=5, row=1)
boutton_ajouter2.grid(column=5, row=2)
boutton_ajouter3.grid(column=5, row=3)

boutton_soustraire1.grid(column=1, row=1)
boutton_soustraire2.grid(column=1, row=2)
boutton_soustraire3.grid(column=1, row=3)

canvas1_1.grid(column=2, row=1)
canvas1_2.grid(column=3, row=1)
canvas1_3.grid(column=4, row=1)
canvas2_1.grid(column=2, row=2)
canvas2_2.grid(column=3, row=2)
canvas2_3.grid(column=4, row=2)
canvas3_1.grid(column=2, row=3)
canvas3_2.grid(column=3, row=3)
canvas3_3.grid(column=4, row=3)

root.mainloop()

AFFICHAGE(MAIN4(MAIN1(),MAIN2(),MAIN3()))
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3208/993259917.py in <module>
#     236 root.mainloop()
#     237
# --> 238 AFFICHAGE(MAIN4(MAIN1(),MAIN2(),MAIN3()))
#
# ~\AppData\Local\Temp/ipykernel_3208/993259917.py in AFFICHAGE(MAIN4)
#      61         canvas1_1.create_text(5,5,text="2",fill="white")
#      62     elif L[0][0] == 3 :
# ---> 63         canvas1_1.create_text(5,5,text="3",fill="white")
#      64     elif L[0][0] == 4 :
#      65         canvas1_1.create_text(5,5,text="4",fill="white")
#
# ~\miniconda3\envs\l1-python\lib\tkinter\__init__.py in create_text(self, *args, **kw)
#    2808     def create_text(self, *args, **kw):
#    2809         """Create text with coordinates x1,y1."""
# -> 2810         return self._create('text', args, kw)
#    2811
#    2812     def create_window(self, *args, **kw):
#
# ...

# %%
import random
import tkinter as tk


def MAIN1 ():
    L1=[1,2,3]
    for i in range (3):
        L1[i]=int(random.randint(0,5))

    return(L1)

def MAIN2 ():
    L2=[1,2,3]
    for i in range (3):
        L2[i]=int(random.randint(0,5))
    return(L2)
    

def MAIN3 ():
    L3=[1,2,3]
    for i in range (3):
        L3[i]=int(random.randint(0,5))
    return(L3)

def MAIN4 (MAIN1,MAIN2,MAIN3):
    L=[MAIN1,MAIN2,MAIN3]
    return(L)

MAIN1()
MAIN2()
MAIN3()
MAIN4

def AFFICHAGE (L1,L2,L3) :
    if L1[0] == 0:
        print(0)
    elif L1[0] == 1:
        print(1)
    elif L1[0] == 2:
        print(2)
    elif L1[0] == 3:
        print(3)
    elif L1[0] == 4:
        print(4)
    elif L1[0] == 5:
        print(5)

    if L2[0] == 0:
        print(0)
    elif L2[0] == 1:
        print(1)
    elif L2[0] == 2:
        print(2)
    elif L2[0] == 3:
        print(3)
    elif L2[0] == 4:
        print(4)
    elif L2[0] == 5:
        print(5)

    if L3[0] == 0:
        print(0)
    elif L3[0] == 1:
        print(1)
    elif L3[0] == 2:
        print(2)
    elif L3[0] == 3:
        print(3)
    elif L3[0] == 4:
        print(4)
    elif L3[0] == 5:
        print(5)
    return()

MAIN1()
AFFICHAGE (MAIN1,MAIN2,MAIN3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3208/1108155529.py in <module>
#      81
#      82 MAIN1()
# ---> 83 AFFICHAGE (MAIN1,MAIN2,MAIN3)
#
# ~\AppData\Local\Temp/ipykernel_3208/1108155529.py in AFFICHAGE(L1, L2, L3)
#      40
#      41 def AFFICHAGE (L1,L2,L3) :
# ---> 42     if L1[0] == 0:
#      43         print(0)
#      44     elif L1[0] == 1:
#
# TypeError: 'function' object is not subscriptable

# %%
import random
import tkinter as tk


def MAIN1 ():
    L1=[1,2,3]
    for i in range (3):
        L1[i]=int(random.randint(0,5))

    return(L1)

def MAIN2 ():
    L2=[1,2,3]
    for i in range (3):
        L2[i]=int(random.randint(0,5))
    return(L2)
    
def MAIN3 ():
    L3=[1,2,3]
    for i in range (3):
        L3[i]=int(random.randint(0,5))
    return(L3)

def MAIN4 (L1,L2,L3):
    L=[L1,L2,L3]
    return(L)



def AFFICHAGE (MAIN4):
    L=MAIN4

###########################################################################
    if L[0][0] == 0:
        canvas1_1.create_text(5,5,text="0",fill="white")
    elif L[0][0] == 1 :
        canvas1_1.create_text(5,5,text="1",fill="white")
    elif L[0][0] == 2 :
        canvas1_1.create_text(5,5,text="2",fill="white")
    elif L[0][0] == 3 :
        canvas1_1.create_text(5,5,text="3",fill="white")
    elif L[0][0] == 4 :
        canvas1_1.create_text(5,5,text="4",fill="white")
    elif L[0][0] == 5 :
        canvas1_1.create_text(5,5,text="5",fill="white")

    if L[0][1] == 0:
        canvas1_2.create_text(5,5,text="0",fill="white")
    elif L[0][1] == 1 :
        canvas1_2.create_text(5,5,text="1",fill="white")
    elif L[0][1] == 2 :
        canvas1_2.create_text(5,5,text="2",fill="white")
    elif L[0][1] == 3 :
        canvas1_2.create_text(5,5,text="3",fill="white")
    elif L[0][1] == 4 :
        canvas1_2.create_text(5,5,text="4",fill="white")
    elif L[0][1] == 5 :
        canvas1_2.create_text(5,5,text="5",fill="white")

    if L[0][2] == 0:
        canvas1_3.create_text(5,5,text="0",fill="white")
    elif L[0][2] == 1 :
        canvas1_3.create_text(5,5,text="1",fill="white")
    elif L[0][2] == 2 :
        canvas1_3.create_text(5,5,text="2",fill="white")
    elif L[0][2] == 3 :
        canvas1_3.create_text(5,5,text="3",fill="white")
    elif L[0][2] == 4 :
        canvas1_3.create_text(5,5,text="4",fill="white")
    elif L[0][2] == 5 :
        canvas1_3.create_text(5,5,text="5",fill="white")
########################################################################

    if L[1][0] == 0:
        canvas2_1.create_text(5,5,text="0",fill="white")
    elif L[1][0] == 1 :
        canvas2_1.create_text(5,5,text="1",fill="white")
    elif L[1][0] == 2 :
        canvas2_1.create_text(5,5,text="2",fill="white")
    elif L[1][0] == 3 :
        canvas2_1.create_text(5,5,text="3",fill="white")
    elif L[1][0] == 4 :
        canvas2_1.create_text(5,5,text="4",fill="white")
    elif L[1][0] == 5 :
        canvas2_1.create_text(5,5,text="5",fill="white")

    if L[1][1] == 0:
        canvas2_2.create_text(5,5,text="0",fill="white")
    elif L[1][1] == 1 :
        canvas2_2.create_text(5,5,text="1",fill="white")
    elif L[1][1] == 2 :
        canvas2_2.create_text(5,5,text="2",fill="white")
    elif L[1][1] == 3 :
        canvas2_2.create_text(5,5,text="3",fill="white")
    elif L[1][1] == 4 :
        canvas2_2.create_text(5,5,text="4",fill="white")
    elif L[1][1] == 5 :
        canvas2_2.create_text(5,5,text="5",fill="white")

    if L[1][2] == 0:
        canvas2_3.create_text(5,5,text="0",fill="white")
    elif L[1][2] == 1 :
        canvas2_3.create_text(5,5,text="1",fill="white")
    elif L[1][2] == 2 :
        canvas2_3.create_text(5,5,text="2",fill="white")
    elif L[1][2] == 3 :
        canvas2_3.create_text(5,5,text="3",fill="white")
    elif L[1][2] == 4 :
        canvas2_3.create_text(5,5,text="4",fill="white")
    elif L[1][2] == 5 :
        canvas2_3.create_text(5,5,text="5",fill="white")

############################################################################


    if L[3][0] == 0:
        canvas3_1.create_text(5,5,text="0",fill="white")
    elif L[3][0] == 1 :
        canvas3_1.create_text(5,5,text="1",fill="white")
    elif L[3][0] == 2 :
        canvas3_1.create_text(5,5,text="2",fill="white")
    elif L[3][0] == 3 :
        canvas3_1.create_text(5,5,text="3",fill="white")
    elif L[3][0] == 4 :
        canvas3_1.create_text(5,5,text="4",fill="white")
    elif L[3][0] == 5 :
        canvas3_1.create_text(5,5,text="5",fill="white")

    if L[3][1] == 0:
        canvas3_2.create_text(5,5,text="0",fill="white")
    elif L[3][1] == 1 :
        canvas3_2.create_text(5,5,text="1",fill="white")
    elif L[3][1] == 2 :
        canvas3_2.create_text(5,5,text="2",fill="white")
    elif L[3][1] == 3 :
        canvas3_2.create_text(5,5,text="3",fill="white")
    elif L[3][1] == 4 :
        canvas3_2.create_text(5,5,text="4",fill="white")
    elif L[3][1] == 5 :
        canvas3_2.create_text(5,5,text="5",fill="white")

    if L[3][2] == 0:
        canvas3_3.create_text(5,5,text="0",fill="white")
    elif L[3][2] == 1 :
        canvas3_3.create_text(5,5,text="1",fill="white")
    elif L[3][2] == 2 :
        canvas3_3.create_text(5,5,text="2",fill="white")
    elif L[3][2] == 3 :
        canvas3_3.create_text(5,5,text="3",fill="white")
    elif L[3][2] == 4 :
        canvas3_3.create_text(5,5,text="4",fill="white")
    elif L[3][2] == 5 :
        canvas3_3.create_text(5,5,text="5",fill="white")

    return(L)



MAIN1()
MAIN2()
MAIN3()

AFFICHAGE(MAIN4(MAIN1(),MAIN2(),MAIN3()))
# Out:
# 0
# [[0, 4, 4], [3, 4, 3], [1, 1, 1]]

# %%
canvas.create_text(5,5,text="1",fill="white")

# %%
import tkinter as tk 

CANVAS_WIDTH, CANVAS_HEIGHT = 100, 100

root = tk.Tk()

root.title(" Mon Dessin ")
#création des widgets

canvas = tk.Canvas(root, width = CANVAS_WIDTH, height = CANVAS_HEIGHT, bg="black", bd=10, relief="raised")

canvas.create_text(60,60,text="1",fill="white")

canvas.grid()
root.mainloop()
